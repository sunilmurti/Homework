# %%
import pandas as pd
xlsx2015 = 'https://github.com/sunilmurti/Final-Project/files/632770/2015.xlsx'
xlsx2014 = 'https://github.com/sunilmurti/Final-Project/files/632783/2014.xlsx'
xlsx2013 = 'https://github.com/sunilmurti/Final-Project/files/632792/2013.xlsx'
xlsx2012 = 'https://github.com/sunilmurti/Final-Project/files/632795/2012.xlsx'
xlsx2011 = 'https://github.com/sunilmurti/Final-Project/files/632850/2011.xlsx'
xlsx2010 = 'https://github.com/sunilmurti/Final-Project/files/632859/2010.xlsx'
xlsx2009 = 'https://github.com/sunilmurti/Final-Project/files/632860/2009.xlsx'
xlsx2008 = 'https://github.com/sunilmurti/Final-Project/files/632874/2008.xlsx'
xlsx2007 = 'https://github.com/sunilmurti/Final-Project/files/632876/2007.xlsx'
xlsx2006 = 'https://github.com/sunilmurti/Final-Project/files/632875/2006.xlsx'
xlsx2005 = 'https://github.com/sunilmurti/Final-Project/files/632873/2005.xlsx'
xlsx2004 = 'https://github.com/sunilmurti/Final-Project/files/632871/2004.xlsx'
xlsx2003 = 'https://github.com/sunilmurti/Final-Project/files/632870/2003.xlsx'
xlsx2002 = 'https://github.com/sunilmurti/Final-Project/files/632868/2002.xlsx'
xlsx2001 = 'https://github.com/sunilmurti/Final-Project/files/632872/2001.xlsx'
xlsx2000 = 'https://github.com/sunilmurti/Final-Project/files/632869/2000.xlsx'

yr2015 = pd.read_excel(xlsx2015)     
yr2014 = pd.read_excel(xlsx2014)
yr2013 = pd.read_excel(xlsx2013)
yr2012 = pd.read_excel(xlsx2012)     
yr2011 = pd.read_excel(xlsx2011)
yr2010 = pd.read_excel(xlsx2010)
yr2009 = pd.read_excel(xlsx2009)     
yr2008 = pd.read_excel(xlsx2008)
yr2007 = pd.read_excel(xlsx2007)
yr2006 = pd.read_excel(xlsx2006)     
yr2005 = pd.read_excel(xlsx2005)
yr2004 = pd.read_excel(xlsx2004)
yr2003 = pd.read_excel(xlsx2003)     
yr2002 = pd.read_excel(xlsx2002)
yr2001 = pd.read_excel(xlsx2001)
yr2000 = pd.read_excel(xlsx2000)

# %%
yr2015
# Out:
#                                                 Table 8      Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement             NaN
# 1                                by State by City, 2015             NaN
# 2                                                 State            City
# 3                                               ALABAMA       Abbeville
# 4                                                   NaN      Adamsville
# 5                                                   NaN         Addison
# 6                                                   NaN       Alabaster
# 7                                                   NaN     Albertville
# 8                                                   NaN  Alexander City
# 9                                                   NaN      Aliceville
# 10                                                  NaN       Andalusia
# 11                                                  NaN        Anniston
# ...

# %%
yr2014
# Out:
#                                                 Table 8      Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement             NaN
# 1                                by State by City, 2014             NaN
# 2                                                 State            City
# 3                                               ALABAMA       Abbeville
# 4                                                   NaN      Adamsville
# 5                                                   NaN         Addison
# 6                                                   NaN       Alabaster
# 7                                                   NaN     Albertville
# 8                                                   NaN  Alexander City
# 9                                                   NaN      Aliceville
# 10                                                  NaN        Anniston
# 11                                                  NaN            Arab
# ...

# %%
yr2013
# Out:
#                                                 Table 8      Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement             NaN
# 1                                by State by City, 2013             NaN
# 2                                                 State            City
# 3                                               ALABAMA       Abbeville
# 4                                                   NaN      Adamsville
# 5                                                   NaN         Addison
# 6                                                   NaN       Alabaster
# 7                                                   NaN  Alexander City
# 8                                                   NaN      Aliceville
# 9                                                   NaN       Andalusia
# 10                                                  NaN        Anniston
# 11                                                  NaN            Arab
# ...

# %%
yr2012
# Out:
#                                                 Table 8      Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement             NaN
# 1                                by State by City, 2012             NaN
# 2                                                 State            City
# 3                                               ALABAMA       Abbeville
# 4                                                   NaN      Adamsville
# 5                                                   NaN         Addison
# 6                                                   NaN       Alabaster
# 7                                                   NaN  Alexander City
# 8                                                   NaN      Aliceville
# 9                                                   NaN        Anniston
# 10                                                  NaN            Arab
# 11                                                  NaN         Ashford
# ...

# %%
yr2011
# Out:
#                                                 Table 8      Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement             NaN
# 1                                by State by City, 2011             NaN
# 2                                                 State            City
# 3                                              ALABAMA2       Abbeville
# 4                                                   NaN      Adamsville
# 5                                                   NaN         Addison
# 6                                                   NaN       Alabaster
# 7                                                   NaN     Albertville
# 8                                                   NaN  Alexander City
# 9                                                   NaN       Andalusia
# 10                                                  NaN        Anniston
# 11                                                  NaN            Arab
# ...

# %%
yr2010
# Out:
#                                                 Table 8      Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement             NaN
# 1                                by State by City, 2010             NaN
# 2                                                 State            City
# 3                                               ALABAMA       Abbeville
# 4                                                   NaN      Adamsville
# 5                                                   NaN         Addison
# 6                                                   NaN       Alabaster
# 7                                                   NaN     Albertville
# 8                                                   NaN  Alexander City
# 9                                                   NaN      Aliceville
# 10                                                  NaN      Andalusia2
# 11                                                  NaN        Anderson
# ...

# %%
yr2009
# Out:
#                                                 Table 8      Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement             NaN
# 1                               by State by City, 2009              NaN
# 2                                                 State            City
# 3                                               ALABAMA       Abbeville
# 4                                                   NaN      Adamsville
# 5                                                   NaN         Addison
# 6                                                   NaN       Alabaster
# 7                                                   NaN     Albertville
# 8                                                   NaN  Alexander City
# 9                                                   NaN     Aliceville2
# 10                                                  NaN       Andalusia
# 11                                                  NaN        Anniston
# ...

# %%
yr2008
# Out:
#                                                 Table 8      Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement             NaN
# 1                               by State by City, 2008              NaN
# 2                                                 State            City
# 3                                               ALABAMA       Abbeville
# 4                                                   NaN         Addison
# 5                                                   NaN  Alexander City
# 6                                                   NaN      Aliceville
# 7                                                   NaN       Andalusia
# 8                                                   NaN        Anniston
# 9                                                   NaN            Arab
# 10                                                  NaN         Ardmore
# 11                                                  NaN            Argo
# ...

# %%
yr2007
# Out:
#                                                 Table 8                  \
# 0                     Offenses Known to Law Enforcement             NaN
# 1                               by State by City, 2007              NaN
# 2                                                 State            City
# 3                                               ALABAMA       Abbeville
# 4                                                   NaN      Adamsville
# 5                                                   NaN         Addison
# 6                                                   NaN       Alabaster
# 7                                                   NaN  Alexander City
# 8                                                   NaN      Aliceville
# 9                                                   NaN       Andalusia
# 10                                                  NaN        Anniston
# 11                                                  NaN            Arab
# ...

# %%
yr2006
# Out:
#                                                 Table 8      Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement             NaN
# 1                               by State by City, 2006              NaN
# 2                                                 State            City
# 3                                               ALABAMA       Abbeville
# 4                                                   NaN      Adamsville
# 5                                                   NaN       Alabaster
# 6                                                   NaN      Aliceville
# 7                                                   NaN       Andalusia
# 8                                                   NaN        Anniston
# 9                                                   NaN         Ardmore
# 10                                                  NaN         Ashford
# 11                                                  NaN        Ashville
# ...

# %%
yr2005
# Out:
#                                                 Table 8      Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement             NaN
# 1                               by State by City, 2005              NaN
# 2                                                 State            City
# 3                                               ALABAMA       Abbeville
# 4                                                   NaN      Adamsville
# 5                                                   NaN  Alexander City
# 6                                                   NaN      Aliceville
# 7                                                   NaN       Andalusia
# 8                                                   NaN        Anniston
# 9                                                   NaN         Ardmore
# 10                                                  NaN          Ariton
# 11                                                  NaN         Ashford
# ...

# %%
yr2004
# Out:
#                                                 Table 8  Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement         NaN
# 1          by City 10,000 and over in Population, 2004          NaN
# 2                                         City by state  Population
# 3                                               ALABAMA         NaN
# 4                                           Albertville       18008
# 5                                        Alexander City       15064
# 6                                              Anniston       23905
# 7                                                Athens       19999
# 8                                                Auburn       47230
# 9                                              Bessemer       29298
# 10                                           Birmingham      238167
# 11                                              Cullman       14489
# 12                                               Daphne       17813
# ...

# %%
yr2003
# Out:
#                                                 Table 8  Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement         NaN
# 1          by City 10,000 and over in Population, 2003          NaN
# 2                                                   NaN         NaN
# 3                                         City by state  Population
# 4                                               ALABAMA         NaN
# 5                                             Alabaster       24956
# 6                                          Albertville2       17658
# 7                                        Alexander City       14879
# 8                                              Anniston       23868
# 9                                                Athens       19612
# 10                                               Auburn       45533
# 11                                           Birmingham      240176
# 12                                              Cullman       14103
# ...

# %%
yr2002
# Out:
#                                                 Table 8  Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement         NaN
# 1          by City 10,000 and over in Population, 2002          NaN
# 2                                         City by state  Population
# 3                                                   NaN         NaN
# 4                                               ALABAMA         NaN
# 5                                                   NaN
# 6                                             Alabaster       22819
# 7                                           Albertville       17400
# 8                                        Alexander City       15141
# 9                                              Anniston       24491
# 10                                               Athens       19135
# 11                                               Auburn       43368
# 12                                           Birmingham      244972
# ...

# %%
yr2001
# Out:
#                                                 Table 8  Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement         NaN
# 1          by City 10,000 and over in Population, 2001          NaN
# 2                                         City by state  Population
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# 5                                              ALABAMA2         NaN
# 6                                                   NaN
# 7                                             Alabaster       22707
# 8                                        Alexander City       15066
# 9                                              Anniston       24370
# 10                                               Athens       19041
# 11                                               Auburn       43154
# 12                                           Birmingham      243762
# ...

# %%
yr2000
# Out:
#                                                 Table 8  Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement         NaN
# 1          by City 10,000 and over in Population, 2000          NaN
# 2                                         City by state  Population
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# 5                                              ALABAMA2         NaN
# 6                                                   NaN         NaN
# 7                                        Alexander City       16450
# 8                                              Anniston       26075
# 9                                                Athens       20661
# 10                                               Auburn       43354
# 11                                             Bessemer       31186
# 12                                           Birmingham      253868
# ...
